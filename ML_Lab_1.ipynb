# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")  #make sure the file is in the same folder
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f503fc02e5e7> in <cell line: 0>()
# ----> 1 df = pd.read_csv("train.csv")  #make sure the file is in the same folder
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv("/content/train.csv")  #make sure the file is in the same folder
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a52fc114f6b2> in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/train.csv")  #make sure the file is in the same folder
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv("/content/tested.csv")  #make sure the file is in the same folder

# %%
print("✅ Data Loaded Successfully!\n")
df.head()
# Out:
# ✅ Data Loaded Successfully!
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.dropna(inplace=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8047edcf38d7> in <cell line: 0>()
# ----> 1 df.dropna(inplace=true)
#
# NameError: name 'true' is not defined

# %%
df.dropna(inplace=True)

# %%
df['Age'].fillna(o,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a44859d0629f> in <cell line: 0>()
# ----> 1 df['Age'].fillna(o,inplace=True)
#
# NameError: name 'o' is not defined

# %%
df['Age'].fillna(0,inplace=True)
# Out:
# <ipython-input-16-bc4b6a9f5ad3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(0,inplace=True)

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# <ipython-input-17-7ee7fe972bc2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.rename(columns={'SibSp':'Siblings_Spouses'},inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# female    44
# male      43
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['Age'].hist(bins=20 , color = 'skyblue')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %%
df['Age'].hist(bins=5)   # Very broad groups
# Out:
# <Axes: >

# %%
df['Age'].hist(bins=50)  # Super detailed
# Out:
# <Axes: >

# %%
df['Fare'].hist(bins=25,color='green')
plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Passenger Count")
plt.show()

# %%
df['Sex'].value_counts().plot(kind='bar',color='orange')
plt.title("Passenger Gender Count")
plt.xlabel("Gender")
# Out:
# Text(0.5, 0, 'Gender')

# %%
df['Sex'].value_counts().plot(kind='bar',color='orange')
plt.title("Passenger Gender Count")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    1.0
# male      0.0
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean().plot(kind='bar',color='teal')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df.groupby('Pclass')['Survived'].mean().plot(kind='bar',color='pink')
plt.title("Survival Rate by Class")
plt.ylabel("Survival rate")
plt.xlabel("Passenger Class")
plt.show()

# %%
df.plot(kind='scatter',x='Age',y='Fare',color=red)
plt.title("Age vs Fare")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-ba6f2d884fc0> in <cell line: 0>()
# ----> 1 df.plot(kind='scatter',x='Age',y='Fare',color=red)
#       2 plt.title("Age vs Fare")
#       3 plt.show()
#
# NameError: name 'red' is not defined

# %%
df.plot(kind='scatter',x='Age',y='Fare',color='red')
plt.title("Age vs Fare")
plt.show()

# %%
df['Age'].mean()
# Out:
# np.float64(39.247126436781606)

# %%
df['Fare'].mean()
# Out:
# np.float64(98.10919770114941)

# %%
import seaborn as sns
sns.boxplot(x='Pclass',y='Fare',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0
# 28                            Brady, Mr. John Bertram    male  41.0
#
#     Siblings_Spouses  Parch       Ticket      Fare            Cabin Embarked
# 12                 1      0        21228   82.2667              B45        S
# 14                 1      0  W.E.P. 5734   61.1750              E31        S
# 24                 1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                 Name     Sex   Age  \
# 404                     Frauenthal, Mr. Isaac Gerald    male  43.0
# 405     Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0
# 407                       Widener, Mr. George Dunton    male  50.0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0
#
#      Siblings_Spouses  Parch         Ticket      Fare Cabin Embarked
# 404                 1      0          17765   27.7208   D40        C
# 405                 0      0  SC/PARIS 2166   13.8625   D38        C
# 407                 1      1         113503  211.5000   C80        C
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Gender_encoded'] = le.fit_transform(df['Gender'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-4681a2c0b995> in <cell line: 0>()
# ----> 1 df['Gender_encoded'] = le.fit_transform(df['Gender'])
#
# ...

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0
# 28                            Brady, Mr. John Bertram    male  41.0
#
#     Siblings_Spouses  Parch       Ticket      Fare            Cabin Embarked
# 12                 1      0        21228   82.2667              B45        S
# 14                 1      0  W.E.P. 5734   61.1750              E31        S
# 24                 1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...

# %%
df['Sex_encoded']=le.fit_transform(df['Sex'])

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0
# 28                            Brady, Mr. John Bertram    male  41.0
#
#     Siblings_Spouses  Parch       Ticket      Fare            Cabin Embarked  \
# 12                 1      0        21228   82.2667              B45        S
# 14                 1      0  W.E.P. 5734   61.1750              E31        S
# 24                 1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0
# 28                            Brady, Mr. John Bertram    male  41.0
#
#     Siblings_Spouses  Parch       Ticket      Fare            Cabin Embarked  \
# 12                 1      0        21228   82.2667              B45        S
# 14                 1      0  W.E.P. 5734   61.1750              E31        S
# 24                 1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...
